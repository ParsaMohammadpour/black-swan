# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import random
from graph_holder import *
from benford import *

# %%
NODE_NUMBER = 1000
MAX_EDGE_NUMBER = (NODE_NUMBER) * (NODE_NUMBER - 1) / 2
EDGE_PROBABILITY = 0.05
EDGE_NUMBER = int(MAX_EDGE_NUMBER * EDGE_PROBABILITY)  # Approximately 0.05 of max possible edge number
GRAPH_NUMBER = 1
SIMULATION_NUMBER = 1
COLOR = ['red', 'green', 'blue', 'gray', 'yellow', 'brown', 'black']

# %% [markdown]
# Small World

# %%
small_world_holder = GraphHolder(graph_no = GRAPH_NUMBER, node_no = NODE_NUMBER, edge_prob = EDGE_PROBABILITY, graph_type = 'small world')
small_world_holder.show_degree_distribution()
plt.show()
# Out:
# Graph No:  0

# %% [markdown]
# Random

# %%
random_holder = GraphHolder(graph_no = GRAPH_NUMBER, node_no = NODE_NUMBER, edge_prob = EDGE_PROBABILITY, graph_type = 'random')
random_holder.show_degree_distribution()
plt.show()
# Out:
# graph no:  0

# %% [markdown]
# Scale Free

# %%
scale_free_holder = GraphHolder(graph_no = GRAPH_NUMBER, node_no = NODE_NUMBER, edge_prob = EDGE_PROBABILITY, graph_type = 'scale free')
scale_free_holder.show_degree_distribution()
plt.show()
# Out:
# Graph no:  0

# %%
benford = Benford()
benford.show_distribution_and_formula()
plt.show()
